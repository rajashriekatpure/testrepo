# %% [markdown]
# # My Jupyter Notebook on IBM Watson Studio

# %% [markdown]
# **Rajashri Ekatpure**
#
# Data Scientist

# %% [markdown]
# *I am intrested in data science beacuse i am curious about how insights from data helps businesses to make dicisions*

# %% [markdown]
# ### Have a look at the following code

# %%
languages_dic = {"Rlanguage": "Statistical work", "Python": "Analysis work"}
languages_dic.pop("Python")
# Out:
# 'Analysis work'

# %% [markdown]
# The reasons why i am intrested in data science
# * Curious about AI
# * Problem Solving attitude
# * Intrested in software
# * Intrest in learning computetional languages

# %% [markdown]
# ___

# %% [markdown]
# ***

# %% [markdown]
# One
#
# Two
#
# Three
#
# 1
#
# 2
#
# 3
